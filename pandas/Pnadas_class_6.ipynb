# %% [markdown]
# #Data Transformation

# %%
import pandas as pd

# %%
s = pd.Series(['cat', 'cow', 'dog', ])
print('Series:\n')
s
# Out:
# Series:
# 0    cat
# 1    cow
# 2    dog
# dtype: object

# %%
print("Mapping:\n")
s.map({"cat": "kitten", "cow": "calf"})
# Out:
# Mapping:
# 0    kitten
# 1      calf
# 2       NaN
# dtype: object

# %%
df = pd.DataFrame(
    [
        ('carrot', 'red', 1),
        ('papaya', 'yellow', 0),
        ('mango', 'yellow', 0),
        ('apple', 'red', 0),
    ],
    columns=['species', 'color', 'type']
)
df
# Out:
#   species   color  type
# 0  carrot     red     1
# 1  papaya  yellow     0
# 2   mango  yellow     0
# 3   apple     red     0

# %%
print("Dataframe before Mapping: ")
print(df)

mappings = {
    'carrot': 'veg',
    'papaya': 'fruit',
    'mango': 'king',
    'apple': 'fruit',
}
# Out:
# Dataframe before Mapping:
#   species   color   type
# 0  carrot     red    veg
# 1  papaya  yellow  fruit
# 2   mango  yellow    NaN
# 3   apple     red    NaN

# %%
mappings
# Out:
# {'carrot': 'veg', 'papaya': 'fruit', 'mango': 'king', 'apple': 'fruit'}

# %%
df['type'] = df['species'].map(mappings)
print("DataFram after mapping")
df
# Out:
# DataFram after mapping
#   species   color   type
# 0  carrot     red    veg
# 1  papaya  yellow  fruit
# 2   mango  yellow   king
# 3   apple     red  fruit

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon','Pastrami', 'corned beef', 'Bacon',
'pastrami', 'honey ham', 'nova lox'],
'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

# %%
data['food'] = data['food'].str.lower()

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
data['animal'] = data.food.map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
# continuous

# %%
bins = [18, 25, 35, 60, 100]

# %%
cats = pd.cut(ages, bins)

# %%
cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
cats.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]], dtype='interval[int64, right]')

# %%
pd.value_counts(cats)
# Out:
# <ipython-input-25-4707cd3120e0>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(cats)
# (18, 25]     5
# (25, 35]     3
# (35, 60]     3
# (60, 100]    1
# Name: count, dtype: int64
