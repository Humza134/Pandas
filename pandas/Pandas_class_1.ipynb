# %% [markdown]
# #Pandas

# %% [markdown]
# #Series

# %%
import pandas as pd

# %%
products = ["A", "B", "C", "D"]
products
# Out:
# ['A', 'B', 'C', 'D']

# %%
type(products)
# Out:
# list

# %%
product_categories = pd.Series(products)

# %%
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
type(product_categories)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
start_dates_deposits = pd.Series({
    '7/4/2024': 2000,
    '1/3/2002': 3000,
    '10/4/2023': 5000
})

# %%
start_dates_deposits
# Out:
# 7/4/2024     2000
# 1/3/2002     3000
# 10/4/2023    5000
# dtype: int64

# %%
start_dates_deposits.sum()
# Out:
# 10000

# %%
start_dates_deposits.min()
# Out:
# 2000

# %%
start_dates_deposits.idxmin()
# Out:
# '7/4/2024'

# %%
start_dates_deposits.head()
# Out:
# 7/4/2024     2000
# 1/3/2002     3000
# 10/4/2023    5000
# dtype: int64

# %%
start_dates_deposits.tail()
# Out:
# 7/4/2024     2000
# 1/3/2002     3000
# 10/4/2023    5000
# dtype: int64

# %%
s1 = pd.Series([12,24,36,12,6,0,12,36])
s1
# Out:
# 0    12
# 1    24
# 2    36
# 3    12
# 4     6
# 5     0
# 6    12
# 7    36
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
s1.values
# Out:
# array([12, 24, 36, 12,  6,  0, 12, 36])

# %% [markdown]
# #Customize indices: Lables

# %%
s1.index = ['Apples', 'Eggs', 'Breads',"Bananas", 'Mangoes', "Grapes", 'Peech', 'Lemon']

# %%
s1
# Out:
# Apples     12
# Eggs       24
# Breads     36
# Bananas    12
# Mangoes     6
# Grapes      0
# Peech      12
# Lemon      36
# dtype: int64

# %%
s1.name = 'Fruits'

# %%
s1
# Out:
# Apples     12
# Eggs       24
# Breads     36
# Bananas    12
# Mangoes     6
# Grapes      0
# Peech      12
# Lemon      36
# Name: Fruits, dtype: int64

# %% [markdown]
# # Selecting / Retreiveing data from a series

# %%
s1["Grapes"]
# Out:
# 0

# %%
s1['Lemon']
# Out:
# 36

# %%
s1["Eggs": "Grapes"]
# Out:
# Eggs       24
# Breads     36
# Bananas    12
# Mangoes     6
# Grapes      0
# Name: Fruits, dtype: int64

# %%
s1[1:5]
# Out:
# Eggs       24
# Breads     36
# Bananas    12
# Mangoes     6
# Name: Fruits, dtype: int64

# %%
s1.shape
# Out:
# (8,)

# %% [markdown]
# #DataFrame

# %%
array_a = np.array([[3,2,1], [6,3,2]])
array_a
# Out:
# array([[3, 2, 1],
#        [6, 3, 2]])

# %%
pd.DataFrame(array_a)
# Out:
#    0  1  2
# 0  3  2  1
# 1  6  3  2

# %%
type(pd.DataFrame(array_a))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(array_a, columns = ['Column 1', 'Column 2', 'Column 3'])
df
# Out:
#    Column 1  Column 2  Column 3
# 0         3         2         1
# 1         6         3         2

# %%
df = pd.DataFrame(array_a, columns = ['Column 1', 'Column 2', 'Column 3'], index = ['Row 1', 'Row 2'])
df
# Out:
#        Column 1  Column 2  Column 3
# Row 1         3         2         1
# Row 2         6         3         2

# %%
df = pd.DataFrame({'name':['Ali','Usman','Raza','Shani'],
                  'age':[18,64,17,23]})

# %%
df
# Out:
#     name  age
# 0    Ali   18
# 1  Usman   64
# 2   Raza   17
# 3  Shani   23

# %%
df.shape
# Out:
# (4, 2)

# %%
df['status'] = ['Live', 'Dead', 'Live', 'Live']
df
# Out:
#     name  age status
# 0    Ali   18   Live
# 1  Usman   64   Dead
# 2   Raza   17   Live
# 3  Shani   23   Live

# %%
df['gender'] = ['Male','Female','Male','Female']
df
# Out:
#     name  age status  Gender  gender
# 0    Ali   18   Live    Male    Male
# 1  Usman   64   Dead  Female  Female
# 2   Raza   17   Live    Male    Male
# 3  Shani   23   Live  Female  Female

# %%
del df['Gender']
df
# Out:
#     name  age status  gender
# 0    Ali   18   Live    Male
# 1  Usman   64   Dead  Female
# 2   Raza   17   Live    Male
# 3  Shani   23   Live  Female

# %%
data = pd.read_excel('/content/employee.xlsx', index_col='Serial')
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN
# 17        2156    Engineer  Production  45.0   89000.0
# 18        2123  Office Boy    Accounts  27.0   45000.0

# %% [markdown]
# # Acessing a single column from data

# %%
data['Designation']
# Out:
# Serial
# 1        Manager
# 2        Officer
# 3        Officer
# 4        Manager
# 5     Office Boy
# 6     Accountant
# 7     Accountant
# 8        Officer
# 9        Manager
# 10      Engineer
# 11       Officer
# 12    Accountant
# 13      Engineer
# 14       Officer
# 15       Officer
# 16       Officer
# 17      Engineer
# 18    Office Boy
# Name: Designation, dtype: object

# %%
type(data['Designation'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Accessing mltiple columns

# %%
data.columns
# Out:
# Index(['Emp_ID', 'Designation', 'Department', 'Age', 'Salary'], dtype='object')

# %%
data['Emp_ID', 'Salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Emp_ID', 'Salary')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-56f00c9607eb> in <cell line: 0>()
# ----> 1 data['Emp_ID', 'Salary']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('Emp_ID', 'Salary')

# %%
data[['Emp_ID', 'Salary']]
# Out:
#         Emp_ID    Salary
# Serial
# 1         1101  200000.0
# 2         1107   80000.0
# 3         1203       NaN
# 4         1005  120000.0
# 5         2123   45000.0
# 6         2451  100000.0
# 7         1111  110000.0
# 8         1001   75000.0
# 9         1234       NaN
# 10        2156   89000.0
# 11        6543  100000.0
# 12        3214  123000.0
# 13        2156   89000.0
# 14        1098  100000.0
# 15        2912   90000.0
# 16        1222       NaN
# 17        2156   89000.0
# 18        2123   45000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 1 to 18
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Emp_ID       18 non-null     int64
#  1   Designation  18 non-null     object
#  2   Department   16 non-null     object
#  3   Age          17 non-null     float64
#  4   Salary       15 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 864.0+ bytes

# %%
data.shape
# Out:
# (18, 5)

# %%
data.head()
# Out:
#         Emp_ID Designation Department   Age    Salary
# Serial
# 1         1101     Manager   Accounts  50.0  200000.0
# 2         1107     Officer         IT  30.0   80000.0
# 3         1203     Officer         HR  28.0       NaN
# 4         1005     Manager         HR  45.0  120000.0
# 5         2123  Office Boy   Accounts  27.0   45000.0

# %%
data.sample(5)
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 4         1005     Manager          HR  45.0  120000.0
# 14        1098     Officer          IT  25.0  100000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 17        2156    Engineer  Production  45.0   89000.0

# %% [markdown]
# # Generate Data from data

# %%
data.Salary = data.Salary+data.Salary*0.10

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  220000.0
# 2         1107     Officer          IT  30.0   88000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  132000.0
# 5         2123  Office Boy    Accounts  27.0   49500.0
# 6         2451  Accountant         NaN  34.0  110000.0
# 7         1111  Accountant    Accounts   NaN  121000.0
# 8         1001     Officer          IT  25.0   82500.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   97900.0
# 11        6543     Officer  Production  29.0  110000.0
# 12        3214  Accountant     Account  49.0  135300.0
# 13        2156    Engineer  Production  45.0   97900.0
# 14        1098     Officer          IT  25.0  110000.0
# 15        2912     Officer          IT  31.0   99000.0
# 16        1222     Officer         NaN  25.0       NaN
# 17        2156    Engineer  Production  45.0   97900.0
# 18        2123  Office Boy    Accounts  27.0   49500.0

# %%
data['Salary_tax']= [salary*0.10 if salary>=200000 else salary*.08 if salary>=150000 else salary*.05 if salary>=100000 else salary*.03 if salary>=50000 else salary for salary in data.Salary]

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary  Salary_tax
# Serial
# 1         1101     Manager    Accounts  50.0  220000.0     22000.0
# 2         1107     Officer          IT  30.0   88000.0      2640.0
# 3         1203     Officer          HR  28.0       NaN         NaN
# 4         1005     Manager          HR  45.0  132000.0      6600.0
# 5         2123  Office Boy    Accounts  27.0   49500.0     49500.0
# 6         2451  Accountant         NaN  34.0  110000.0      5500.0
# 7         1111  Accountant    Accounts   NaN  121000.0      6050.0
# 8         1001     Officer          IT  25.0   82500.0      2475.0
# 9         1234     Manager          IT  23.0       NaN         NaN
# 10        2156    Engineer  Production  45.0   97900.0      2937.0
# 11        6543     Officer  Production  29.0  110000.0      5500.0
# 12        3214  Accountant     Account  49.0  135300.0      6765.0
# 13        2156    Engineer  Production  45.0   97900.0      2937.0
# 14        1098     Officer          IT  25.0  110000.0      5500.0
# 15        2912     Officer          IT  31.0   99000.0      2970.0
# 16        1222     Officer         NaN  25.0       NaN         NaN
# 17        2156    Engineer  Production  45.0   97900.0      2937.0
# 18        2123  Office Boy    Accounts  27.0   49500.0     49500.0

# %%
data['Final_Salary'] = data['Salary'] - data['Salary_tax']
data
# Out:
#         Emp_ID Designation  Department   Age    Salary  Salary_tax  \
# Serial
# 1         1101     Manager    Accounts  50.0  220000.0     22000.0
# 2         1107     Officer          IT  30.0   88000.0      2640.0
# 3         1203     Officer          HR  28.0       NaN         NaN
# 4         1005     Manager          HR  45.0  132000.0      6600.0
# 5         2123  Office Boy    Accounts  27.0   49500.0     49500.0
# 6         2451  Accountant         NaN  34.0  110000.0      5500.0
# 7         1111  Accountant    Accounts   NaN  121000.0      6050.0
# 8         1001     Officer          IT  25.0   82500.0      2475.0
# 9         1234     Manager          IT  23.0       NaN         NaN
# 10        2156    Engineer  Production  45.0   97900.0      2937.0
# 11        6543     Officer  Production  29.0  110000.0      5500.0
# 12        3214  Accountant     Account  49.0  135300.0      6765.0
# 13        2156    Engineer  Production  45.0   97900.0      2937.0
# 14        1098     Officer          IT  25.0  110000.0      5500.0
# 15        2912     Officer          IT  31.0   99000.0      2970.0
# 16        1222     Officer         NaN  25.0       NaN         NaN
# 17        2156    Engineer  Production  45.0   97900.0      2937.0
# 18        2123  Office Boy    Accounts  27.0   49500.0     49500.0
#
#         Final_Salary
# Serial
# 1           198000.0
# 2            85360.0
# 3                NaN
# 4           125400.0
# 5                0.0
# 6           104500.0
# 7           114950.0
# 8            80025.0
# 9                NaN
# 10           94963.0
# 11          104500.0
# 12          128535.0
# 13           94963.0
# 14          104500.0
# 15           96030.0
# 16               NaN
# 17           94963.0
# 18               0.0
